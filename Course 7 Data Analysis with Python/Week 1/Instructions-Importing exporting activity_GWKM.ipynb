# %%
import pandas as pd
# %pip install --upgrade pandas
import numpy as np

# %%
# Import the CSV in a dataframe
df_cities = pd.read_csv("cities.csv")

# %%
# Add a column to the dataframe
df_cities["New Column"] = np.nan

# %%
# Perform describe and info on dataframe
df_cities.describe()
# Out:
#              LatD      "LatM"      "LatS"      "LonD"      "LonM"      "LonS"  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000  128.000000
# mean    38.820312   30.765625   27.492188   93.250000   27.742188   26.960938
# std      5.200596   16.426158   18.977814   15.466499   16.927937   18.727807
# min     26.000000    1.000000    0.000000   71.000000    0.000000    0.000000
# 25%     35.000000   16.000000   11.000000   80.000000   14.000000   11.000000
# 50%     39.000000   31.000000   24.000000   89.500000   26.500000   23.500000
# 75%     42.250000   45.000000   47.000000  103.250000   40.250000   47.000000
# max     50.000000   59.000000   59.000000  123.000000   58.000000   59.000000
#
#        New Column
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LatD        128 non-null    int64
#  1    "LatM"     128 non-null    int64
#  2    "LatS"     128 non-null    int64
#  3    "NS"       128 non-null    object
#  4    "LonD"     128 non-null    int64
#  5    "LonM"     128 non-null    int64
#  6    "LonS"     128 non-null    int64
#  7    "EW"       128 non-null    object
#  8    "City"     128 non-null    object
#  9    "State"    128 non-null    object
#  10  New Column  0 non-null      float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 11.1+ KB

# %%
# Export and save this data as cities1.csv
df_cities.to_csv("cities1.csv")

# %%
# Import xlsx in a dataframe
df_car = pd.read_excel("CarSalesByModelStart.xlsx")

# %%
# Add a column to the dataframe
df_car["New Column"]=np.nan

# %%
# Perform describe and info on dataframe
df_car.describe()
# Out:
#               Year    Dealer ID  Quantity Sold        Profit  New Column
# count  1200.000000  1200.000000     1200.00000   1200.000000         0.0
# mean   2018.500000  1281.800000       17.99750  24974.055208         NaN
# std       0.500208    72.453672        9.97432  17370.750612         NaN
# min    2018.000000  1212.000000        2.00000   4600.000000         NaN
# 25%    2018.000000  1217.000000       11.00000  13500.000000         NaN
# 50%    2018.500000  1256.000000       18.00000  18500.000000         NaN
# 75%    2019.000000  1336.000000       24.00000  28922.812500         NaN
# max    2019.000000  1402.000000       48.00000  83875.000000         NaN

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           1200 non-null   int64
#  1   Month          1200 non-null   object
#  2   Date           1200 non-null   datetime64[ns]
#  3   Model          1200 non-null   object
#  4   Dealer ID      1200 non-null   int64
#  5   Quantity Sold  1200 non-null   int64
#  6   Profit         1200 non-null   float64
#  7   New Column     0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 75.1+ KB

# %%
# Export and save this data as CarSalesByModelStart1.xlsx
df_car.to_excel("CarSalesByModelStart1.xlsx")

# %%
# Import the Json in dataframe
df_jay = pd.read_json("Jay.json")

# %%
# Add a column to the dataframe
df_jay["New Column"] = np.nan

# %%
# Perform describe and info on dataframe
df_jay.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories  New Column
# count  169.000000  169.000000  169.000000   164.000000         0.0
# mean    63.846154  107.461538  134.047337   375.800000         NaN
# std     42.299949   14.510259   16.450434   266.377134         NaN
# min     15.000000   80.000000  100.000000    50.300000         NaN
# 25%     45.000000  100.000000  124.000000   250.925000         NaN
# 50%     60.000000  105.000000  131.000000   318.600000         NaN
# 75%     60.000000  111.000000  141.000000   387.600000         NaN
# max    300.000000  159.000000  184.000000  1860.400000         NaN

# %%
df_jay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Duration    169 non-null    int64
#  1   Pulse       169 non-null    int64
#  2   Maxpulse    169 non-null    int64
#  3   Calories    164 non-null    float64
#  4   New Column  0 non-null      float64
# dtypes: float64(2), int64(3)
# memory usage: 7.9 KB

# %%
# Export and save this data as Jay1.json
df_jay.to_json("Jay1.json")

# %%
# Presention iloc vs loc
df_jay
# Out:
#      Duration  Pulse  Maxpulse  Calories  New Column
# 0          60    110       130     409.1         NaN
# 1          60    117       145     479.0         NaN
# 2          60    103       135     340.0         NaN
# 3          45    109       175     282.4         NaN
# 4          45    117       148     406.0         NaN
# ..        ...    ...       ...       ...         ...
# 164        60    105       140     290.8         NaN
# 165        60    110       145     300.4         NaN
# 166        60    115       145     310.2         NaN
# 167        75    120       150     320.4         NaN
# 168        75    125       150     330.4         NaN
#
# [169 rows x 5 columns]

# %%
df_jay.iloc[1,2]
# Out:
# 145

# %%
df_jay.loc[1, "Maxpulse"]
# Out:
# 145

# %%
df_jay.iloc[1:3,2:4]
# Out:
#    Maxpulse  Calories
# 1       145     479.0
# 2       135     340.0

# %%
df_jay.loc[1:3, "Maxpulse":"New Column"]
# Out:
#    Maxpulse  Calories  New Column
# 1       145     479.0         NaN
# 2       135     340.0         NaN
# 3       175     282.4         NaN

# %%
df_jay.iloc[[1,3],2]
# Out:
# 1    145
# 3    175
# Name: Maxpulse, dtype: int64

# %%
df_jay.loc[[1,3], "Maxpulse"]
# Out:
# 1    145
# 3    175
# Name: Maxpulse, dtype: int64

# %%
df_jay.iloc[::3]
# Out:
#      Duration  Pulse  Maxpulse  Calories  New Column
# 0          60    110       130     409.1         NaN
# 3          45    109       175     282.4         NaN
# 6          60    110       136     374.0         NaN
# 9          60     98       124     269.0         NaN
# 12         60    106       128     345.3         NaN
# 15         60     98       120     215.2         NaN
# 18         60    103       123     323.0         NaN
# 21         45    100       119     282.0         NaN
# 24         60    102       126     334.5         NaN
# 27         60    103       132       NaN         NaN
# 30         60     92       115     243.0         NaN
# 33         60     93       113     223.0         NaN
# 36         60    102       127     300.5         NaN
# 39         45    104       129     266.0         NaN
# 42         60    100       122     329.4         NaN
# 45         60     99       119     273.0         NaN
# 48         45    108       129     298.0         NaN
# ...
